# %% [markdown]
# ### Import Spectra class and changeFileExtensions

# %%
from project.spectra import Spectra
from project.extension import changeFileExtensions

# %% [markdown]
# ### Standardize the data format

# %% [markdown]
# After identifying catalogs with Type Ia supernovae spectra and downloading the data in flm format, the files are in a spectrum folder.
# ![image.png](attachment:image.png)

# %%
changeFileExtensions("spectrum", ".csv") # standardize the data format

# %% [markdown]
# The file extension is changed to csv with ```changeFileExtensions```. ![image.png](attachment:image.png)

# %% [markdown]
# ### Get spectra and store the spectra

# %%
instance = Spectra("spectrum/sn1999ej-19991030.csv")  # initialize class instance

# %%
instance.getSpectra(spectrumPath="output/spectra.png") # spectra.png is stored in outout folder

# %% [markdown]
# ### Analysis of the spectrum and store the plot

# %%
instance.getFit("output/fit.png") # fit.png is stored in outout folder

# %% [markdown]
# Below are additional functionalities that are initially not in the workflow diagram.

# %%
print("amplitude: {}".format(instance.getAmplitude()))
print("offset: {}".format(instance.getOffset()))
print("mean: {}".format(instance.getMean()))
print("standard deviation: {}".format(instance.getSigma()))
print("FWHM: {}".format(instance.getFWHM()))
# Out:
# amplitude: -1.7144203738840107
# offset: 2.8787576229138425
# mean: 6216.795168340535
# standard deviation: 73.83255668907601
# FWHM: 173.875671002774
